# %%
import IPython
import spacy
from zshot import PipelineConfig, displacy
from zshot.linker import Linker, LinkerSMXM
from zshot.utils.data_models import Entity

config = PipelineConfig(
    entities=[
        Entity(name="company", description="A company, abbreviated as co., is a legal entity representing an association of people, whether natural, legal or a mixture of both, with a specific objective. Company members share a common purpose and unite to achieve specific, declared goals."),
        Entity(name="chemical compound", description="Any of a large class of chemical compounds in which one or more \
  atoms of carbon are covalently linked to atoms of other elements, most commonly hydrogen, oxygen, or nitrogen")
    ],
    linker=LinkerSMXM()
)
nlp = spacy.blank("en")
nlp.add_pipe("zshot", config=config, last=True)

text = "Acetamide (systematic name: ethanamide) is an organic compound with the formula CH3CONH2. It is the simplest amide derived from acetic acid. It finds some use as a plasticizer and as an industrial solvent."
doc = nlp(text)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/transformers/utils/import_utils.py:1076, in _LazyModule._get_module(self, module_name)
#    1075 try:
# -> 1076     return importlib.import_module("." + module_name, self.__name__)
#    1077 except Exception as e:
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:42
#      31 from ...modeling_outputs import (
#      32     BaseModelOutputWithPastAndCrossAttentions,
#      33     BaseModelOutputWithPoolingAndCrossAttentions,
#    (...)
#      40     TokenClassifierOutput,
#      41 )
# ---> 42 from ...modeling_utils import PreTrainedModel
#      43 from ...pytorch_utils import apply_chunking_to_forward, find_pruneable_heads_and_indices, prune_linear_layer
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/transformers/modeling_utils.py:78
#      77 if is_accelerate_available():
# ---> 78     from accelerate import __version__ as accelerate_version
#      79     from accelerate import dispatch_model, infer_auto_device_map, init_empty_weights
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/accelerate/__init__.py:3
#       1 __version__ = "0.26.1"
# ----> 3 from .accelerator import Accelerator
#       4 from .big_modeling import (
#       5     cpu_offload,
#       6     cpu_offload_with_hook,
#    (...)
#      11     load_checkpoint_and_dispatch,
#      12 )
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/accelerate/accelerator.py:35
#      33 import torch.utils.hooks as hooks
# ---> 35 from .checkpointing import load_accelerator_state, load_custom_state, save_accelerator_state, save_custom_state
#      36 from .data_loader import DataLoaderDispatcher, prepare_data_loader, skip_first_batches
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/accelerate/checkpointing.py:24
#      22 from torch.cuda.amp import GradScaler
# ---> 24 from .utils import (
#      25     MODEL_NAME,
#      26     OPTIMIZER_NAME,
#      27     RNG_STATE_NAME,
#      28     SAFE_MODEL_NAME,
#      29     SAFE_WEIGHTS_NAME,
#      30     SAMPLER_NAME,
#      31     SCALER_NAME,
#      32     SCHEDULER_NAME,
#      33     WEIGHTS_NAME,
#      34     get_pretty_name,
#      35     is_tpu_available,
#      36     is_xpu_available,
#      37     save,
#      38 )
#      41 if is_tpu_available(check_device=False):
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/accelerate/utils/__init__.py:152
#     151 from .bnb import has_4bit_bnb_layers, load_and_quantize_model
# --> 152 from .fsdp_utils import load_fsdp_model, load_fsdp_optimizer, save_fsdp_model, save_fsdp_optimizer
#     153 from .launch import (
#     154     PrepareForLaunch,
#     155     _filter_args,
#    (...)
#     160     prepare_tpu,
#     161 )
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/accelerate/utils/fsdp_utils.py:25
#      24 if is_torch_version(">=", FSDP_PYTORCH_VERSION) and is_torch_distributed_available():
# ---> 25     import torch.distributed.checkpoint as dist_cp
#      26     from torch.distributed.checkpoint.default_planner import DefaultLoadPlanner, DefaultSavePlanner
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/torch/distributed/checkpoint/__init__.py:7
#       1 from .metadata import (
#       2     TensorStorageMetadata,
#       3     BytesStorageMetadata,
#       4     ChunkStorageMetadata,
#       5     Metadata,
#       6 )
# ----> 7 from .state_dict_loader import load_state_dict, load
#       8 from .state_dict_saver import save_state_dict, save
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/torch/distributed/checkpoint/state_dict_loader.py:12
#      11 from .planner import LoadPlanner
# ---> 12 from .default_planner import DefaultLoadPlanner
#      14 from .utils import _DistWrapper, _all_gather_keys
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/torch/distributed/checkpoint/default_planner.py:14
#      13 from torch.distributed._shard._utils import narrow_tensor_by_index
# ---> 14 from torch.distributed._tensor import DTensor
#      17 from torch.distributed.checkpoint.planner import (
#      18     SavePlanner,
#      19     LoadPlanner,
#    (...)
#      24     WriteItemType,
#      25 )
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/torch/distributed/_tensor/__init__.py:6
#       5 import torch
# ----> 6 import torch.distributed._tensor.ops
#       7 import torch.distributed._tensor.random as random
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/torch/distributed/_tensor/ops/__init__.py:2
#       1 # Copyright (c) Meta Platforms, Inc. and affiliates
# ----> 2 from .embedding_ops import *  # noqa: F403
#       3 from .matrix_ops import *  # noqa: F403
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/torch/distributed/_tensor/ops/embedding_ops.py:5
#       4 import torch
# ----> 5 from torch.distributed._tensor.op_schema import OpSchema, OutputSharding
#       6 from torch.distributed._tensor.ops.utils import register_prop_rule
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/torch/distributed/_tensor/op_schema.py:6
#       5 from torch._ops import OpOverload
# ----> 6 from torch.distributed._tensor.placement_types import DTensorSpec
#       7 from torch.distributed.device_mesh import DeviceMesh
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/torch/distributed/_tensor/placement_types.py:7
#       6 import torch
# ----> 7 import torch.distributed._functional_collectives as funcol
#       8 import torch.distributed.distributed_c10d as c10d
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/torch/distributed/_functional_collectives.py:9
#       8 from ._functional_collectives_impl import _register_tensor_wrapper
# ----> 9 from torch.fx.experimental.proxy_tensor import (
#      10     get_innermost_proxy_mode,
#      11 )
#      12 from torch._custom_ops import impl_abstract
#
# ImportError: cannot import name 'get_innermost_proxy_mode' from 'torch.fx.experimental.proxy_tensor' (/home/araxal/anaconda3/envs/AudioSep/lib/python3.10/site-packages/torch/fx/experimental/proxy_tensor.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 3
#       1 import IPython
#       2 import spacy
# ----> 3 from zshot import PipelineConfig, displacy
#       4 from zshot.linker import Linker, LinkerSMXM
#       5 from zshot.utils.data_models import Entity
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/zshot/__init__.py:1
# ----> 1 from zshot.zshot import MentionsExtractor, Linker, Zshot, PipelineConfig, RelationsExtractor  # noqa: F401
#       2 from zshot.utils.displacy.displacy import displacy  # noqa: F401
#       4 __version__ = '0.0.8'
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/zshot/zshot.py:10
#       7 from spacy.tokens import Doc
#       8 from spacy.util import registry as spacy_registry, ensure_path
# ---> 10 from zshot.linker import Linker
#      11 from zshot.mentions_extractor import MentionsExtractor
#      12 from zshot.pipeline_config import PipelineConfig
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/zshot/linker/__init__.py:4
#       2 from zshot.linker.linker_regen.linker_regen import LinkerRegen  # noqa: F401
#       3 from zshot.linker.linker import Linker  # noqa: F401
# ----> 4 from zshot.linker.linker_smxm import LinkerSMXM  # noqa: F401
#       5 from zshot.linker.linker_tars import LinkerTARS  # noqa: F401
#       6 from zshot.linker.linker_ensemble import LinkerEnsemble  # noqa: F401
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/zshot/linker/linker_smxm.py:9
#       7 from zshot.linker.linker import Linker
#       8 from zshot.utils.data_models import Span
# ----> 9 from zshot.utils.models.smxm.model import BertTaggerMultiClass
#      10 from zshot.utils.models.smxm.utils import (
#      11     get_entities_names_descriptions,
#      12     smxm_predict
#      13 )
#      15 ONTONOTES_MODEL_NAME = "ibm/smxm"
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/zshot/utils/models/smxm/model.py:4
#       1 import random
#       3 import torch
# ----> 4 from transformers import BertModel, BertPreTrainedModel, logging
#       6 logging.set_verbosity_error()
#       9 class BertTaggerMultiClass(BertPreTrainedModel):
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/transformers/utils/import_utils.py:1067, in _LazyModule.__getattr__(self, name)
#    1065 elif name in self._class_to_module.keys():
#    1066     module = self._get_module(self._class_to_module[name])
# -> 1067     value = getattr(module, name)
#    1068 else:
#    1069     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/transformers/utils/import_utils.py:1066, in _LazyModule.__getattr__(self, name)
#    1064     value = self._get_module(name)
#    1065 elif name in self._class_to_module.keys():
# -> 1066     module = self._get_module(self._class_to_module[name])
#    1067     value = getattr(module, name)
#    1068 else:
#
# File ~/anaconda3/envs/AudioSep/lib/python3.10/site-packages/transformers/utils/import_utils.py:1078, in _LazyModule._get_module(self, module_name)
#    1076     return importlib.import_module("." + module_name, self.__name__)
#    1077 except Exception as e:
# -> 1078     raise RuntimeError(
#    1079         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1080         f" traceback):\n{e}"
#    1081     ) from e
#
# RuntimeError: Failed to import transformers.models.bert.modeling_bert because of the following error (look up to see its traceback):
# cannot import name 'get_innermost_proxy_mode' from 'torch.fx.experimental.proxy_tensor' (/home/araxal/anaconda3/envs/AudioSep/lib/python3.10/site-packages/torch/fx/experimental/proxy_tensor.py)

# %%
displacy.render(doc, style="ent", jupyter=True)
